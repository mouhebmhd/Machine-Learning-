# %% [markdown]
# <div style="font-size:'16px'">
#  🎓 Énoncé de TP
#
# **Matière :** **Machine Learning**
# **Année Universitaire :** **2024-2025**
# **Enseignant :** **Mouheb Mehdoui**
#
# ---
#
# ### 📚 Objectifs du TP
# - Comprendre les concepts fondamentaux du Machine Learning.
# - Appliquer des algorithmes sur des jeux de données réels.
# - Analyser et interpréter les résultats obtenus.
#
# ### 📅 Date de rendu
# Mois  **Octobre 2024**.
#
# ### 📝 Instructions
# 1. Assurez-vous de respecter les consignes fournies.
# 2. Soumettez votre rapport au format PDF.
#
# ### 💡 Conseils
# - N'hésitez pas à poser des questions si vous avez des doutes.
# - Travaillez en groupe pour enrichir vos connaissances.
# </div>

# %% [markdown]
# <font size=5 > <p style="color:#FFC107;text-align:center"> Quels sont les facteurs qui influencent le prix de l'assurance maladie ?

# %% [markdown]
# <img src="https://i.imgur.com/zTnvOcb.jpg" width="800">

# %% [markdown]
# <font size='2'>De nombreux facteurs qui influencent le montant que vous payez pour une assurance santé ne sont pas sous votre contrôle. Néanmoins, il est utile de comprendre quels sont ces facteurs. Voici quelques facteurs qui influencent le coût des primes d'assurance santé
#
# * **Âge :** l'âge du bénéficiaire principal
#
# * **Sexe :** le genre du souscripteur d'assurance, femme ou homme
#
# * **IMC :** Indice de masse corporelle, fournissant une compréhension du poids corporel par rapport à la taille, un indice objectif du poids corporel (kg / m^2) en utilisant le rapport taille/poids, idéalement de 18,5 à 24,9
#
# * **Enfants :** nombre d'enfants couverts par l'assurance santé / nombre de personnes à charge
#
# * **Fumeur :** tabagisme
#
# * **Région :** la zone de résidence du bénéficiaire aux États-Unis, nord-est, sud-est, sud-ouest, nord-ouest

# %% [markdown]
# <font size='5'><p style="color:#FFC107;text-align:center"> Analyse Exploratoire de Données et Visualisation </p></font>

# %%
# TODO:importer la bibliothèque pandas en tant que pd

# TODO:importer la bibliothèque numpy en tant que np

# TODO:importer la bibliothèque matplotlib.pyplot pour la visualisation


# TODO:importer la bibliothèque seaborn pour des visualisations statistiques
# TODO:Importer la bibliothèque warnings pour gérer les avertissements
# TODO:ignorer les avertissements pour une meilleure lisibilité

# %%
# TODO: Importez le jeu de données en utilisant pd.read_csv() et assignez-le à une variable.
# Astuce : utiliser la fonction read_csv de la bibliothèque pandas (pd)

# TODO: Affichez les premières lignes du jeu de données pour vérifier qu'il a été correctement importé.
# Astuce : utiliser la fonction head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# TODO: Utilisez df.shape pour afficher les dimensions du DataFrame (nombre de lignes et de colonnes).
# Astuce : cela vous permettra de vérifier la taille du jeu de données que vous avez importé.
# Out:
# (1338, 7)

# %%
# TODO: Utilisez df.describe() pour obtenir un résumé statistique des colonnes numériques du DataFrame.
# Astuce : cela inclut des informations telles que la moyenne, l'écart type, les valeurs minimales et maximales.
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# TODO: Utilisez df.dtypes pour afficher les types de données de chaque colonne du DataFrame.
# Astuce : cela vous aidera à comprendre la nature des données que vous manipulez.
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
# TODO: Utilisez df.isnull().sum() pour vérifier le nombre de valeurs manquantes dans chaque colonne du DataFrame.
# Astuce : cela vous permettra d'identifier les colonnes qui nécessitent un traitement des valeurs manquantes.
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# <font size='3'>Nous n'avons aucune valeur manquante, ce qui est très bien.<br>
# Passons maintenant à l'EDA avec quelques graphiques intéressants :) Nous allons d'abord voir comment les frais sont répartis en fonction des facteurs donnés.</font>

# %%
# Importation de la bibliothèque Seaborn pour la visualisation
sns.set(style='whitegrid')  # Définir le style de la grille à 'whitegrid' pour un fond clair avec une grille
import seaborn

# Création d'une figure avec un seul sous-graphe de taille 12x8 pouces
f, ax = plt.subplots(1, 1, figsize=(12, 8))

# Tracer la distribution des charges à partir du DataFrame df
# 'charges' est la colonne contenant les valeurs à visualiser
# kde=True indique que l'on souhaite également afficher la courbe de densité
# La couleur du tracé est définie sur 'c' (cyan)
ax = sns.distplot(df['charges'], kde=True, color='c')

# Ajouter un titre au graphique
plt.title('Distribution of Charges')
# Out:
# Text(0.5, 1.0, 'Distribution of Charges')

# %% [markdown]
# <font size='3'>Cette distribution est asymétrique à droite. Pour la rapprocher d'une distribution normale, nous pouvons appliquer le logarithme naturel.</font>

# %%
# Création d'une figure avec un seul sous-graphe de taille 12x8 pouces
f, ax = plt.subplots(1, 1, figsize=(12, 8))

# Tracer la distribution des charges après transformation logarithmique
# On applique une transformation logarithmique base 10 à la colonne 'charges' du DataFrame df
# La courbe de densité est affichée grâce à kde=True
# La couleur du tracé est définie sur 'r' (rouge)
ax = sns.distplot(np.log10(df['charges']), kde=True, color='r')

# %% [markdown]
# <font size='3'>Maintenant, examinons les frais par région.</font>

# %%
# Importation des bibliothèques nécessaires pour la visualisation
import seaborn as sns
import matplotlib.pyplot as plt

# Supposons que 'df' soit votre DataFrame
# Groupement des charges par région, puis calcul de la somme des charges pour chaque région
# Les valeurs sont ensuite triées par ordre croissant
charges = df['charges'].groupby(df.region).sum().sort_values(ascending=True)

# Création d'une figure avec un seul sous-graphe de taille 8x6 pouces
f, ax = plt.subplots(1, 1, figsize=(8, 6))

# Tracer un diagramme à barres avec les régions sur l'axe x et les charges correspondantes sur l'axe y
# La palette de couleurs utilisée est 'Blues'
sns.barplot(x=charges.index, y=charges.values, palette='Blues', ax=ax)

# Définir le titre du graphique
ax.set_title('Distribution of Charges')

# Afficher le graphique
plt.xticks(rotation=45)  # Rotation des étiquettes de l'axe x si nécessaire pour une meilleure lisibilité
plt.show()

# %% [markdown]
# <font size='3'>Ainsi, en général, les frais médicaux les plus élevés se trouvent dans le Sud-Est et les plus bas dans le Sud-Ouest. En tenant compte de certains facteurs (sexe, tabagisme, avoir des enfants), voyons comment cela varie selon les régions.</font>

# %%
# Création d'une figure avec un seul sous-graphe de taille 12x8 pouces
f, ax = plt.subplots(1, 1, figsize=(12, 8))

# Tracer un diagramme à barres avec les régions sur l'axe x et les charges sur l'axe y
# L'argument 'hue' permet de distinguer les charges selon le sexe ('sex') des individus
# La palette de couleurs utilisée est 'cool'
ax = sns.barplot(x='region', y='charges', hue='sex', data=df, palette='cool')

# %%
# Création d'une figure avec un seul sous-graphe de taille 12x8 pouces
f, ax = plt.subplots(1, 1, figsize=(12, 8))

# Tracer un diagramme à barres avec les régions sur l'axe x et les charges sur l'axe y
# L'argument 'hue' permet de distinguer les charges selon le statut de fumeur ('smoker')
# La palette de couleurs utilisée est 'Reds_r', un dégradé de rouge inversé
ax = sns.barplot(x='region', y='charges', hue='smoker', data=df, palette='Reds_r')

# %%
# Création d'une figure avec un seul sous-graphe de taille 12x8 pouces
f, ax = plt.subplots(1, 1, figsize=(12, 8))

# Tracer un diagramme à barres avec les régions sur l'axe x et les charges sur l'axe y
# L'argument 'hue' permet de distinguer les charges selon le nombre d'enfants ('children')
# La palette de couleurs utilisée est 'Set1', qui offre une gamme de couleurs vives
ax = sns.barplot(x='region', y='charges', hue='children', data=df, palette='Set1')

# %% [markdown]
# <font size='3'>Comme nous pouvons le voir sur ces diagrammes à barres, les frais les plus élevés liés au tabagisme se trouvent toujours dans le Sud-Est, tandis que les plus bas sont dans le Nord-Est. Les personnes dans le Sud-Ouest fument généralement plus que celles du Nord-Est, mais les personnes dans le Nord-Est ont des frais par sexe plus élevés que dans le Sud-Ouest et le Nord-Ouest dans l'ensemble. De plus, les personnes avec des enfants ont tendance à avoir des coûts médicaux plus élevés en général.</font>

# %% [markdown]
# <font size='3'>Analysons maintenant les frais médicaux par âge, IMC et nombre d'enfants en fonction du facteur tabagisme.</font>

# %%
# Tracer un graphique de régression linéaire avec l'âge ('age') sur l'axe des x et les charges ('charges') sur l'axe des y
# La couleur des points est déterminée par le statut de fumeur ('smoker'), utilisant la palette de couleurs 'Set1'
ax = sns.lmplot(x='age', y='charges', data=df, hue='smoker', palette='Set1')

# Tracer un graphique de régression linéaire avec l'indice de masse corporelle ('bmi') sur l'axe des x et les charges ('charges') sur l'axe des y
# La couleur des points est également déterminée par le statut de fumeur ('smoker'), mais cette fois avec la palette 'Set2'
ax = sns.lmplot(x='bmi', y='charges', data=df, hue='smoker', palette='Set2')

# Tracer un graphique de régression linéaire avec le nombre d'enfants ('children') sur l'axe des x et les charges ('charges') sur l'axe des y
# La couleur des points est déterminée par le statut de fumeur ('smoker'), utilisant la palette de couleurs 'Set3'
ax = sns.lmplot(x='children', y='charges', data=df, hue='smoker', palette='Set3')

# %% [markdown]
# <font size='3'>Le tabagisme a le plus grand impact sur les coûts médicaux, même si les coûts augmentent avec l'âge, l'IMC et le nombre d'enfants. De plus, les personnes qui ont des enfants fument généralement moins, ce que montrent également les diagrammes en violon suivants.</font>

# %%
## Conversion des étiquettes d'objets en catégories
# Les colonnes 'sex', 'smoker' et 'region' du DataFrame 'df' sont converties en types de données catégoriels
df[['sex', 'smoker', 'region']] = df[['sex', 'smoker', 'region']].astype('category')

# Affichage des types de données des colonnes du DataFrame
df.dtypes
# Out:
# age            int64
# sex         category
# bmi          float64
# children       int64
# smoker      category
# region      category
# charges      float64
# dtype: object

# %%
# TODO: Importez LabelEncoder depuis sklearn.preprocessing pour convertir les étiquettes de catégorie en valeurs numériques.
# Astuce : cela vous aidera à préparer vos données pour l'apprentissage automatique.

# TODO: Créez une instance de LabelEncoder et utilisez la méthode fit pour ajuster l'encodeur aux valeurs uniques de la colonne 'sex'.
# Astuce : utilisez df.sex.drop_duplicates() pour obtenir les valeurs uniques.

# TODO: Transformez la colonne 'sex' en valeurs numériques à l'aide de la méthode transform de LabelEncoder.
# Astuce : assignez le résultat à df.sex.

# TODO: Répétez les étapes ci-dessus pour la colonne 'smoker'.
# Astuce : ajustez et transformez les valeurs uniques de df.smoker.

# TODO: Répétez les étapes ci-dessus pour la colonne 'region'.
# Astuce : ajustez et transformez les valeurs uniques de df.region.

# TODO: Utilisez df.dtypes pour afficher les types de données des colonnes après la conversion.
# Astuce : cela vous permettra de vérifier que les colonnes catégorielles ont été correctement converties en numériques.
# Out:
# age           int64
# sex           int32
# bmi         float64
# children      int64
# smoker        int32
# region        int32
# charges     float64
# dtype: object

# %%
# TODO: Créez une figure et des axes pour le graphique en utilisant plt.subplots().
# Astuce : définissez la taille de la figure avec figsize pour un meilleur affichage.

# TODO: Utilisez sns.heatmap() pour créer une carte de chaleur des corrélations entre les colonnes du DataFrame.
# Astuce : passez df.corr() comme argument pour obtenir la matrice de corrélation.
# Assurez-vous d'activer l'annotation avec annot=True pour afficher les valeurs de corrélation sur la carte.

# TODO: Utilisez cmap='cool' pour appliquer une palette de couleurs à la carte de chaleur.
# Astuce : cela rendra votre graphique plus esthétique.

# %% [markdown]
# <font size='3' font>Pas de  correlation, sauf celle liée au  tabagisme

# %% [markdown]
# <font size=5><p style="color:#FFC107;text-align:center"> Linear Regression

# %%
# TODO: Importez la fonction train_test_split de sklearn.model_selection sous le nom holdout.
# Astuce : cela vous permettra de diviser votre jeu de données en ensembles d'entraînement et de test.

# TODO: Importez la classe LinearRegression de sklearn.linear_model pour créer votre modèle de régression linéaire.
# Astuce : cela vous aidera à effectuer la régression sur vos données.

# TODO: Importez le module metrics de sklearn pour évaluer les performances du modèle.
# Astuce : cela vous permettra de mesurer la qualité de votre modèle.

# TODO: Séparez les données en variables indépendantes (x) et dépendantes (y).
# Astuce : utilisez df.drop() pour retirer la colonne 'charges' de x, et df['charges'] pour y.

# TODO: Utilisez holdout pour diviser les données en ensembles d'entraînement et de test.
# Astuce : définissez test_size=0.2 pour 20% des données comme ensemble de test, et random_state=0 pour la reproductibilité.

# TODO: Créez une instance de LinearRegression.
# Astuce : cela vous permettra de construire et d'entraîner votre modèle.

# TODO: Entraînez le modèle en utilisant la méthode fit sur les ensembles d'entraînement (x_train, y_train).
# Astuce : cela ajuste les coefficients du modèle en fonction des données.

# TODO: Affichez l'intercepte du modèle entraîné avec print(Lin_reg.intercept_).
# Astuce : cela représente la constante dans l'équation de la régression.

# TODO: Affichez les coefficients du modèle entraîné avec print(Lin_reg.coef_).
# Astuce : cela représente l'impact de chaque variable indépendante sur la variable dépendante.

# TODO: Évaluez le modèle en utilisant la méthode score() sur les ensembles de test (x_test, y_test).
# Astuce : cela vous donnera le coefficient de détermination R^2, indiquant la qualité de la prédiction.
# Out:
# -11661.983908824399
# [  253.99185244   -24.32455098   328.40261701   443.72929547
#  23568.87948381  -288.50857254]
# 0.799874714544996

# %% [markdown]
# <font size='3'>Le résultat que nous avons obtenu est suffisant, mais nous pouvons essayer de l'améliorer un peu en réduisant les caractéristiques non importantes par la suite.</font>

# %%
# TODO: Utilisez la méthode predict() du modèle Lin_reg pour prédire les valeurs de y_test à partir de x_test.
# Astuce : assignez le résultat à la variable y_test_pred.

# TODO: Calculez l'erreur absolue moyenne (Mean Absolute Error) en utilisant metrics.mean_absolute_error().
# Astuce : comparez y_test avec les prédictions y_test_pred et affichez le résultat avec print().

# TODO: Calculez l'erreur quadratique moyenne (Mean Squared Error) avec metrics.mean_squared_error().
# Astuce : cela mesure la moyenne des carrés des erreurs, ce qui vous aide à évaluer la précision du modèle.

# TODO: Calculez la racine de l'erreur quadratique moyenne (Root Mean Squared Error) en utilisant np.sqrt() et metrics.mean_squared_error().
# Astuce : cela vous donnera une idée de l'erreur en utilisant les mêmes unités que la variable dépendante, 'charges'.
# Out:
# Mean Absolute Error: 3930.3332739011385
# Mean Squared Error: 31845929.134159423
# Root Mean Squared Error: 5643.2197488809015

# %% [markdown]
# <font size=5><p style="color:#FFC107;text-align:center"> Polynomial Regression

# %%
# TODO: Importez PolynomialFeatures depuis sklearn.preprocessing pour créer des caractéristiques polynomiales.
# Astuce : cela vous permettra d'ajouter des puissances supplémentaires des caractéristiques existantes.

# TODO: Séparez les données en variables indépendantes (x) en retirant les colonnes 'charges', 'sex', et 'region'.
# Astuce : utilisez df.drop() pour spécifier les colonnes à retirer.

# TODO: Assignez la colonne 'charges' à la variable dépendante (y).
# Astuce : cela représente la valeur que vous souhaitez prédire.

# TODO: Créez une instance de PolynomialFeatures avec un degré de 2.
# Astuce : cela ajoutera des termes quadratiques aux caractéristiques existantes.

# TODO: Transformez les données x en caractéristiques polynomiales en utilisant la méthode fit_transform() de PolynomialFeatures.
# Astuce : assignez le résultat à x_pol.

# TODO: Divisez les données transformées en ensembles d'entraînement et de test avec holdout.
# Astuce : utilisez les données x_pol et y, en conservant test_size=0.2 pour 20% des données comme ensemble de test.

# TODO: Créez une instance de LinearRegression pour le modèle de régression polynomiale.
# Astuce : cela vous permettra de construire et d'entraîner votre modèle.

# TODO: Entraînez le modèle en utilisant la méthode fit sur les ensembles d'entraînement (x_train, y_train).
# Astuce : cela ajuste les coefficients du modèle en fonction des données.

# TODO: Prédisez les valeurs de y_train en utilisant la méthode predict() sur x_train.
# Astuce : assignez le résultat à y_train_pred.

# TODO: Prédisez les valeurs de y_test en utilisant la méthode predict() sur x_test.
# Astuce : assignez le résultat à y_test_pred.

# TODO: Affichez l'intercepte du modèle entraîné avec print(Pol_reg.intercept_).
# Astuce : cela représente la constante dans l'équation de la régression.

# TODO: Affichez les coefficients du modèle entraîné avec print(Pol_reg.coef_).
# Astuce : cela représente l'impact de chaque variable indépendante sur la variable dépendante.

# TODO: Évaluez le modèle en utilisant la méthode score() sur les ensembles de test (x_test, y_test).
# Astuce : cela vous donnera le coefficient de détermination R^2, indiquant la qualité de la prédiction.
# Out:
# -5325.881705253518
# [ 0.00000000e+00 -4.01606591e+01  5.23702019e+02  8.52025026e+02
#  -9.52698471e+03  3.04430186e+00  1.84508369e+00  6.01720286e+00
#   4.20849790e+00 -9.38983382e+00  3.81612289e+00  1.40840670e+03
#  -1.45982790e+02 -4.46151855e+02 -9.52698471e+03]
# 0.8812595703345231

# %%
# TODO: Calculez l'erreur absolue moyenne (Mean Absolute Error) en utilisant metrics.mean_absolute_error().
# Astuce : comparez y_test avec les prédictions y_test_pred et assignez le résultat à une variable pour l'afficher.

# TODO: Calculez l'erreur quadratique moyenne (Mean Squared Error) avec metrics.mean_squared_error().
# Astuce : cela mesure la moyenne des carrés des erreurs, ce qui vous aide à évaluer la précision du modèle.

# TODO: Calculez la racine de l'erreur quadratique moyenne (Root Mean Squared Error) en utilisant np.sqrt() et metrics.mean_squared_error().
# Astuce : cela vous donnera une idée de l'erreur en utilisant les mêmes unités que la variable dépendante, 'charges'.

# TODO: Affichez les résultats calculés pour l'erreur absolue moyenne, l'erreur quadratique moyenne et la racine de l'erreur quadratique moyenne.
# Astuce : utilisez print() pour afficher chaque métrique avec un message explicatif.
# Out:
# Mean Absolute Error: 2824.4950454776445
# Mean Squared Error: 18895160.09878035
# Root Mean Squared Error: 4346.856346692441

# %%
# TODO: Utilisez la méthode predict() de Pol_reg pour prédire les valeurs de y_test à partir de x_test.
# Astuce : assignez le résultat à la variable y_test_pred.

# TODO: Créez un DataFrame en utilisant pd.DataFrame() pour comparer les valeurs réelles avec les valeurs prédites.
# Astuce : utilisez un dictionnaire avec 'Actual' comme clé pour y_test et 'Predicted' comme clé pour y_test_pred.

# TODO: Affichez le DataFrame résultant pour voir la comparaison entre les valeurs réelles et prédites.
# Astuce : cela vous permettra d'évaluer visuellement la précision de votre modèle.
# Out:
#            Actual     Predicted
# 578    9724.53000  12101.156323
# 610    8547.69130  10440.782266
# 569   45702.02235  48541.022951
# 1034  12950.07120  14140.067522
# 198    9644.25250   8636.235727
# ...           ...           ...
# 1084  15019.76005  16712.196281
# 726    6664.68595   8654.565461
# 1132  20709.02034  12372.050609
# 725   40932.42950  41465.617268
# 963    9500.57305  10941.780705
#
# [268 rows x 2 columns]

# %% [markdown]
# <font size='3'> **Conclusion :** Comme nous l'avons précédemment constaté, **le tabagisme** est le plus grand facteur qui influence les frais médicaux, suivi de **l'IMC** et de **l'âge**. **La régression polynomiale** s'est révélée être le meilleur modèle.</font>
